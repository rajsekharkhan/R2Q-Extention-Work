# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

'''print("setup complete")
    print("view")'''

with open('C:/Users/HP/Desktop/MTECH 1ST SEM NOTES/PROJECT BY OWN/src/object sensitivity vs risk simulation/normals_view.txt', "r") as f1:
    lines1 = f1.readlines()
    x1 = [float(line.split(",")[9]) for line in lines1]
    y1 = [float(line.split(",")[8]) for line in lines1]

with open('C:/Users/HP/Desktop/MTECH 1ST SEM NOTES/PROJECT BY OWN/src/object sensitivity vs risk simulation/anomolous_view.txt', 'r') as f2:
    lines2 = f2.readlines()
    x2 = [float(line.split(",")[9]) for line in lines2]
    y2 = [float(line.split(",")[8]) for line in lines2]
    

plt.figure(figsize=(10,6))
plt.title("view")
plt.xlabel("object sensitivity")
plt.ylabel("risk score")

plt.plot(x1, y1, "g--", label=("normal"))
plt.plot(x2, y2, "r--", label =("anomolous"))

plt.legend()
plt.show()
